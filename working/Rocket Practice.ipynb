# %%
from math import sin, cos, log, pi
import numpy
from matplotlib import pyplot
# %matplotlib inline
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16

# %%
#initial conditions
m_s = 50.0
g = 9.81 
p = 1.091
A = 0.5*0.5*pi
v_e = 325.0
C_d = 0.15
m_p0 = 100.0

# %%
T = 40
dt = 0.02
N = int(T/dt) + 1
t = numpy.linspace(0.0, T, N)

# %%
m_p = numpy.zeros(N)
for n in range(N):
    if n*dt <=5:
        m_p[n] = 100 - 20*n*dt
    else:
        m_p[n] = 0

# %%
pyplot.figure(figsize=(10,4))
pyplot.grid(True)
pyplot.xlabel('$t$')
pyplot.ylabel('$m_p$')
pyplot.xlim(0, 50)
pyplot.title('$m_p$ - $t$', fontsize = 18)
pyplot.plot(t, m_p, 'k-', lw=2)

# %%
print(m_p[int(3.2/dt)])
# Out:
# 36.0

# %%
v0 = 0
h0 = 0
def f(u):
    v = u[1]
    h = u[0]
    return numpy.array([v,-g + (1/(m)*m_pdot*v_e\
                                -0.5*1/(m)*p*v*numpy.abs(v)*A*C_d)])

# %%
def euler_step(u, f, dt):
    return u + dt*f(u)

# %%
m_pder = numpy.zeros(N)
for n in range(N):
    if n <= 5/dt:
        m_pder[n] = 20
    else:
        m_pder[n] = 0

# %%
u = numpy.empty((N, 2))
u[0] = numpy.array([h0, v0])

m1 = numpy.zeros(N)
for n in range(N):
    m1[n] = m_s + m_p[n]

for n in range(N-1):  
    m = m1[n]
    m_pdot = m_pder[n]
    u[n+1] = euler_step(u[n], f, dt)

# %%
h = u[:, 0]
v = u[:, 1]

# %%
pyplot.figure(figsize=(16,8))
pyplot.grid(True)
pyplot.xlabel('$t$')
pyplot.ylabel('$h$')
pyplot.ylim(0,1400)
pyplot.plot(t, h, 'k-', lw=2)
pyplot.title('$h$ - $t$')

# %%
pyplot.figure(figsize=(16,8))
pyplot.grid(True)
pyplot.xlabel('$t$')
pyplot.ylabel('$v$')
pyplot.plot(t, v, 'k-', lw=2)
pyplot.title('$v$ - $t$');

# %%
print ('The maximum speed is v = {:.2f} m/s'.format(u[int(5/dt),1]),'occurs at t = 5 s','and the altitude is h = {:.2f} m'\
       .format(u[int(5/dt),0]))
# Out:
# The maximum speed is v = 232.38 m/s occurs at t = 5 s and the altitude is h = 534.84 m

# %%
for n in range(N):
    if u[n,1] < 0:
        print ('The maximum altitude is h = {:.2f} m'.format(u[n, 0]),'occurs at t={}s'. format(n*dt))
        break
# Out:
# The maximum altitude is h = 1354.80 m occurs at t=15.8s
